# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('diabetes.csv')
df.head()
df.Outcome.value_counts()
df.head()
# df.shape
df.columns
X=df.iloc[:,:8]
y=df.iloc[:,8]


df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
# now we will do standardization as range of values in every feature is very different
std=StandardScaler()
X_scaled=std.fit_transform(X)

X=pd.DataFrame(X_scaled,columns=X.columns)

# %%
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %%
classifier=svm.SVC(kernel='linear')
print(classifier.get_params())
# Out:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
# training the support vector machine classifier
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# accuracy score on the training data
X_train_pred=classifier.predict(X_train)
score=accuracy_score(X_train_pred,y_train)
score

pred_test=classifier.predict(X_test)
score_test=accuracy_score(pred_test,y_test)
score_test
# Out:
# 0.7207792207792207

# %%
input_data=(4,110,92,0,0,37,6,0,191,30)
# chaning the array to numpy
input_data_as_numpy_array=np.asarray(input_data)
# reshaping the array
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
input_data_reshaped
# Out:
# array([[  4, 110,  92,   0,   0,  37,   6,   0, 191,  30]])

# %%
input_data_reshaped=std.transform(input_data_reshaped[:,:8])
# Out:
# C:\Users\Rishabh Mishra\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction=classifier.predict(input_data_reshaped)
prediction
# Out:
# C:\Users\Rishabh Mishra\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1])

# %%
if(prediction[0]==0):
    print("Non-Diabitic")
else:
    print("Diabitic")
# Out:
# Diabitic
